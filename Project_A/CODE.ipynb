# %%
import re
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.style.use("default")

from ast import literal_eval

# %% [markdown]
# DATA TO DATAFRAME

# %%
attributeNames={
    "hand":["Hand_L"],
    "thumb":["thumb_01_l","thumb_02_l","thumb_03_l","thumb_end_l"],
    "index":["index_01_l","index_02_l","index_03_l","index_end_l"],
    "middle":["middle_01_l","middle_02_l","middle_03_l","middle_end_l"],
    "ring":["ring_01_l","ring_02_l","ring_03_l","ring_end_l"],
    "pinky":["pinky_01_l","pinky_02_l","pinky_03_l","pinky_end_l"]
}

# %%
def getcoordinates(name,tsText):

    #finding the first match of string in tsText
    pattern="["+name+":]"
    match=re.search(name,tsText)
    if match:
        index=match.end()

        #finding the next "\n"
        match = re.search('[\n]', tsText[index:]) 
        lineLength=match.start()

        #slicing the line we need from the big string
        line=tsText[index+1:index+lineLength]

        #exctracting values from this line
        values=line.split(",")

        return values[0:10]

# %%
def load_data(filename):

    df=pd.DataFrame()
    
    #reading text from file
    textFile=open(filename,"r")
    text=textFile.read()
    textFile.close()
    # print(text)

    #exctracting data for each timestamp
    pattern='ts: [0-9]*\.[0-9]*'
    rawData=re.split(pattern,text)[1:] #i take all data
    # print(rawData)
    # print(rawData[3])

    #going through attributeNames one by one and extracting x y z qx qy qz qw roll pitch yaw for each name 
    # + creating a new line in the data frame containing all the values
    for i in range(len(rawData)):
        docLine={}

        for j in attributeNames.keys():
            for k in range(len(attributeNames[j])):
                name=attributeNames[j][k]
                #print(name)
                x,y,z,qx,qy,qz,qw,roll,pitch,yaw=getcoordinates(name,rawData[i])
                doc={name+"_x":x,
                     name+"_y":y,
                     name+"_z":z,
                     name+"_QX":qx,
                     name+"_QY":qy,
                     name+"_QZ":qz,
                     name+"_QW":qw,
                     name+"_roll":roll,
                     name+"_pitch":pitch,
                     name+"_yaw":yaw}
                docLine.update(doc)

        dfLine=pd.DataFrame(docLine,index=[0])
        df=pd.concat([df,dfLine],ignore_index=True)
    
    # print(df.head(1))         
    # print("(lines,columns)",df.shape)
    return df

# %%
# print(df)

# %%
df=load_data("skeleton_poses.txt")
# df.to_csv('hand_poses.csv')

# %%
df
# Out:
#         Hand_L_x    Hand_L_y     Hand_L_z   Hand_L_QX   Hand_L_QY   Hand_L_QZ  \
# 0      50.017609   88.463943   153.403961    0.674645    0.330493    0.636429
# 1      -2.965618   40.143124   135.297821    0.078674    0.896557    0.337589
# 2      27.818623    51.65107   127.912117     0.09898    0.718092   -0.569787
# 3       9.856056   23.337147   145.917526    0.000909   -0.619405    0.784002
# 4       4.939243     39.2057   143.335022   -0.009247    0.885532   -0.463676
# ...          ...         ...          ...         ...         ...         ...
# 1975   15.328003    30.62788    121.98819    0.105778    0.870925    0.288412
# 1976   81.663788   34.133667    89.921494    0.486036    0.593604   -0.216031
# 1977   41.151661   36.024048   249.017609    0.640988    0.197424    0.710788
# 1978   19.856586   42.017361   135.241562     0.20316    0.709901    0.667869
# 1979   17.132952   34.020069   106.054657    0.446976    0.571119    0.499609
#
# ...

# %%
df=df.astype(float)
df.dtypes
# Out:
# Hand_L_x             float64
# Hand_L_y             float64
# Hand_L_z             float64
# Hand_L_QX            float64
# Hand_L_QY            float64
#                       ...
# pinky_end_l_QZ       float64
# pinky_end_l_QW       float64
# pinky_end_l_roll     float64
# pinky_end_l_pitch    float64
# pinky_end_l_yaw      float64
# Length: 210, dtype: object

# %% [markdown]
# convert data to the correct unit

# %%
def cmtom(x):
    return x/100

def convertcmtom(data):
    return data.filter(regex='x$|y$|z$').apply(cmtom)

print(convertcmtom(df))
# Out:
#       Hand_L_x  Hand_L_y  Hand_L_z  thumb_01_l_x  thumb_01_l_y  thumb_01_l_z  \
# 0     0.500176  0.884639  1.534040      0.467251      0.900360      1.536225
# 1    -0.029656  0.401431  1.352978     -0.033223      0.368633      1.368711
# 2     0.278186  0.516511  1.279121      0.294146      0.540276      1.301846
# 3     0.098561  0.233371  1.459175      0.082907      0.265079      1.468424
# 4     0.049392  0.392057  1.433350      0.038239      0.406555      1.464994
# ...        ...       ...       ...           ...           ...           ...
# 1975  0.153280  0.306279  1.219882      0.150639      0.278636      1.244270
# 1976  0.816638  0.341337  0.899215      0.795684      0.365460      0.880644
# 1977  0.411517  0.360240  2.490176      0.379456      0.354958      2.507786
# 1978  0.198566  0.420174  1.352416      0.166670      0.403154      1.344740
# 1979  0.171330  0.340201  1.060547      0.140372      0.355066      1.046890
#
# ...

# %%
def negate(x):
    return -x

def flipsignqz(data):
    return data.filter(regex='QZ$').apply(negate)

print(flipsignqz(df))
# Out:
#       Hand_L_QZ  thumb_01_l_QZ  thumb_02_l_QZ  thumb_03_l_QZ  thumb_end_l_QZ  \
# 0     -0.636429      -0.818622      -0.734346      -0.717510       -0.717510
# 1     -0.337589      -0.890747      -0.951422      -0.907368       -0.907368
# 2      0.569787       0.257922      -0.373655      -0.249299       -0.249299
# 3     -0.784002       0.132225       0.097649       0.204886        0.204886
# 4      0.463676      -0.293482      -0.321327      -0.339553       -0.339553
# ...         ...            ...            ...            ...             ...
# 1975  -0.288412       0.774355      -0.905086      -0.942404       -0.942404
# 1976   0.216031      -0.377421      -0.234239      -0.164071       -0.164071
# 1977  -0.710788      -0.714437      -0.774308      -0.771702       -0.771702
# 1978  -0.667869      -0.969554      -0.954211      -0.944162       -0.944162
# 1979  -0.499609      -0.888742      -0.893551      -0.898246       -0.898246
#
# ...

# %%
# library(dplyr)
# import dplyr
# data("who")
# select(who, starts_with("newrel"))

# print(df.filter(regex='y$', axis=0))

# print(df.columns)
# def selection(df):
#     a=df.columns.str.endswith('z')
#     if (a.any()==True):
#         return a

# selection(df)

  
# # String to be searched in end of string 
# search ="x"
  
# # boolean series returned with False at place of NaN
# bool_series = data["College"].str.lower().str.endswith(search, na = False)
  
# # displaying filtered dataframe
# data[bool_series]

# print(df.filter(regex='x$')) +++++++++++++

# %%
df.dtypes
# Out:
# Hand_L_x             float64
# Hand_L_y             float64
# Hand_L_z             float64
# Hand_L_QX            float64
# Hand_L_QY            float64
#                       ...
# pinky_end_l_QZ       float64
# pinky_end_l_QW       float64
# pinky_end_l_roll     float64
# pinky_end_l_pitch    float64
# pinky_end_l_yaw      float64
# Length: 210, dtype: object

# %%
# # from __future__ import division

# # from this import d


# def cmtom(x):
#     return x/100

# # colus=['Hand_L_x','Hand_L_y','Hand_L_z','thumb_01_l_x','thumb_01_l_y','thumb_01_l_z','thumb_02_l_y','thumb_02_l_z','thumb_03_l_x','thumb_03_l_y','thumb_03_l_z',
# # 'thumb_end_l_x','thumb_end_l_y','thumb_end_l_z','index_01_l_x','index_01_l_y','index_01_l_z','index_02_l_y','index_02_l_z','index_03_l_x','index_03_l_y','index_03_l_z',
# # 'index_end_l_x','index_end_l_y','index_end_l_z','middle_01_l_x','middle_01_l_y','middle_01_l_z','middle_02_l_y','middle_02_l_z','middle_03_l_x','middle_03_l_y','middle_03_l_z',
# # 'middle_end_l_x','middle_end_l_y','middle_end_l_z','ring_01_l_x','ring_01_l_y','ring_01_l_z','ring_02_l_y','ring_02_l_z','ring_03_l_x','ring_03_l_y','ring_03_l_z',
# # 'ring_end_l_x','ring_end_l_y','ring_end_l_z','pinky_01_l_x','pinky_01_l_y','pinky_01_l_z','pinky_02_l_y','pinky_02_l_z','pinky_03_l_x','pinky_03_l_y','pinky_03_l_z',
# # 'pinky_end_l_x','pinky_end_l_y','pinky_end_l_z']

# # colus=df.filter(regex='x$')
# def convertcmtom(data):

    
#     # for data in data.filter(regex='x$'):
#     #     data.filter(regex='x$').apply(cmtom)
#     # data.filter(regex='x$').apply(cmtom)
#     # data.filter(regex='y$').apply(cmtom)
#     # data.filter(regex='z$').apply(cmtom)
# # df[colus].apply(cmtom)
#     return data.filter(regex='x$|y$|z$').apply(cmtom)
# # re.search(r"Bienvenue chez (?P<chezqui>\w+) ! Tu as (?P<age>\d+) ans ?", "Bienvenue chez olivier ! Tu as 32 ans")
# print(convertcmtom(df))
# # df.filter(regex='x$').apply(cmtom)
# # df.insert(19, "day", a)
# # df.filter(regex='y$').apply(cmtom)
# # df.filter(regex='z$').apply(cmtom)

# def negate(x):
#     return -x

# def flipsignqz(data):
#     return data.filter(regex='QZ$').apply(negate)

# %% [markdown]
# A quaternion (x, y, z, w) in a left-handed coordinate system (x,y,z) should simply become (x, y, -z, w) in a right-handed coordinate system (x, y, -z).

# %%
# df.filter(regex='x$|y$|z$').apply(cmtom)

# %%
# position_ws=df.groupby(['Hand_L_x','Hand_L_y','Hand_L_z','thumb_01_l_x','thumb_01_l_y','thumb_01_l_z','thumb_02_l_x','thumb_02_l_y','thumb_02_l_z','thumb_03_l_x','thumb_03_l_y','thumb_03_l_z',
# 'thumb_end_l_x','thumb_end_l_y','thumb_end_l_z','index_01_l_x','index_01_l_y','index_01_l_z','index_02_l_x','index_02_l_y','index_02_l_z','index_03_l_x','index_03_l_y','index_03_l_z',
# 'index_end_l_x','index_end_l_y','index_end_l_z','middle_01_l_x','middle_01_l_y','middle_01_l_z','middle_02_l_x','middle_02_l_y','middle_02_l_z','middle_03_l_x','middle_03_l_y','middle_03_l_z',
# 'middle_end_l_x','middle_end_l_y','middle_end_l_z','ring_01_l_x','ring_01_l_y','ring_01_l_z','ring_02_l_x','ring_02_l_y','ring_02_l_z','ring_03_l_x','ring_03_l_y','ring_03_l_z',
# 'ring_end_l_x','ring_end_l_y','ring_end_l_z','pinky_01_l_x','pinky_01_l_y','pinky_01_l_z','pinky_02_l_x','pinky_02_l_y','pinky_02_l_z','pinky_03_l_x','pinky_03_l_y','pinky_03_l_z',
# 'pinky_end_l_x','pinky_end_l_y','pinky_end_l_z'])

# rotation_ws=df.groupby(['Hand_L_QX','Hand_L_QY','Hand_L_QZ','thumb_01_l_QX','thumb_01_l_QY','thumb_01_l_QZ','thumb_02_l_QY','thumb_02_l_QZ','thumb_03_l_QX','thumb_03_l_QY','thumb_03_l_QZ',
# 'thumb_end_l_QX','thumb_end_l_QY','thumb_end_l_QZ','index_01_l_QX','index_01_l_QY','index_01_l_QZ','index_02_l_QX','index_02_l_QY','index_02_l_QZ','index_03_l_QX','index_03_l_QY','index_03_l_QZ',
# 'index_end_l_QX','index_end_l_QY','index_end_l_QZ','middle_01_l_QX','middle_01_l_QY','middle_01_l_QZ','middle_02_l_QX','middle_02_l_QY','middle_02_l_QZ','middle_03_l_QX','middle_03_l_QY','middle_03_l_QZ',
# 'middle_end_l_QX','middle_end_l_QY','middle_end_l_QZ','ring_01_l_QX','ring_01_l_QY','ring_01_l_QZ','ring_02_l_QX','ring_02_l_QY','ring_02_l_QZ','ring_03_l_QX','ring_03_l_QY','ring_03_l_QZ',
# 'ring_end_l_QX','ring_end_l_QY','ring_end_l_QZ','pinky_01_l_QX','pinky_01_l_QY','pinky_01_l_QZ','middle_02_l_QX','pinky_02_l_QY','pinky_02_l_QZ','pinky_03_l_QX','pinky_03_l_QY','pinky_03_l_QZ',
# 'pinky_end_l_QX','pinky_end_l_QY','pinky_end_l_QZ'])

# euler=df.groupby(['Hand_L_roll','Hand_L_pitch','Hand_L_yaw','thumb_01_l_roll','thumb_01_l_pitch','thumb_01_l_yaw','thumb_02_l_roll','thumb_02_l_pitch','thumb_02_l_yaw','thumb_03_l_roll','thumb_03_l_pitch','thumb_03_l_yaw',
# 'thumb_end_l_roll','thumb_end_l_pitch','thumb_end_l_yaw','index_01_l_roll','index_01_l_pitch','index_01_l_yaw','index_02_l_roll','index_02_l_pitch','index_02_l_yaw','index_03_l_roll','index_03_l_pitch','index_03_l_yaw',
# 'index_end_l_roll','index_end_l_pitch','index_end_l_yaw','middle_01_l_roll','middle_01_l_pitch','middle_01_l_yaw','middle_02_l_roll','middle_02_l_pitch','middle_02_l_yaw','middle_03_l_roll','middle_03_l_pitch','middle_03_l_yaw',
# 'middle_end_l_roll','middle_end_l_pitch','middle_end_l_yaw','ring_01_l_roll','ring_01_l_pitch','ring_01_l_yaw','ring_02_l_roll','ring_02_l_pitch','ring_02_l_yaw','ring_03_l_roll','ring_03_l_pitch','ring_03_l_yaw',
# 'ring_end_l_roll','ring_end_l_pitch','ring_end_l_yaw','pinky_01_l_roll','pinky_01_l_pitch','pinky_01_l_yaw','pinky_02_l_roll','pinky_02_l_pitch','pinky_02_l_yaw','pinky_03_l_roll','pinky_03_l_pitch','pinky_03_l_yaw',
# 'pinky_end_l_roll','pinky_end_l_pitch','pinky_end_l_yaw'])

# %%
df.loc[:0]
# Out:
#     Hand_L_x   Hand_L_y    Hand_L_z  Hand_L_QX  Hand_L_QY  Hand_L_QZ  \
# 0  50.017609  88.463943  153.403961   0.674645   0.330493   0.636429
#
#    Hand_L_QW  Hand_L_roll  Hand_L_pitch  Hand_L_yaw  ...  pinky_end_l_x  \
# 0    0.17489   -101.09272     47.998539   92.444099  ...      51.824371
#
#    pinky_end_l_y  pinky_end_l_z  pinky_end_l_QX  pinky_end_l_QY  \
# 0       96.13784     155.812286       -0.530542        0.531879
#
#    pinky_end_l_QZ  pinky_end_l_QW  pinky_end_l_roll  pinky_end_l_pitch  \
# 0       -0.370932        0.545929         97.530724         -10.786309
#
#    pinky_end_l_yaw
# 0        -80.68354
#
# [1 rows x 210 columns]

# %%
df.filter(regex='x$|y$|z$')
# Out:
#        Hand_L_x   Hand_L_y    Hand_L_z  thumb_01_l_x  thumb_01_l_y  \
# 0     50.017609  88.463943  153.403961     46.725128     90.036003
# 1     -2.965618  40.143124  135.297821     -3.322281     36.863331
# 2     27.818623  51.651070  127.912117     29.414574     54.027637
# 3      9.856056  23.337147  145.917526      8.290710     26.507921
# 4      4.939243  39.205700  143.335022      3.823879     40.655537
# ...         ...        ...         ...           ...           ...
# 1975  15.328003  30.627880  121.988190     15.063892     27.863562
# 1976  81.663788  34.133667   89.921494     79.568390     36.545982
# 1977  41.151661  36.024048  249.017609     37.945610     35.495846
# 1978  19.856586  42.017361  135.241562     16.667049     40.315449
# 1979  17.132952  34.020069  106.054657     14.037152     35.506618
#
#       thumb_01_l_z  thumb_02_l_x  thumb_02_l_y  thumb_02_l_z  thumb_03_l_x  \
# 0       153.622543     45.441483     92.883545    155.101807     45.231827
# ...

# %%
# from pyntcloud import PyntCloud

# cloud = PyntCloud(pd.DataFrame(
#     # same arguments that you are passing to visualize_pcl
#     data=np.hstack((points, colors)),
#     columns=["x", "y", "z", "red", "green", "blue"]))

# cloud.to_file("output.ply")

# %%
df=df.astype(str)

# %%
df.columns
# Out:
# Index(['Hand_L_x', 'Hand_L_y', 'Hand_L_z', 'Hand_L_QX', 'Hand_L_QY',
#        'Hand_L_QZ', 'Hand_L_QW', 'Hand_L_roll', 'Hand_L_pitch', 'Hand_L_yaw',
#        ...
#        'pinky_end_l_x', 'pinky_end_l_y', 'pinky_end_l_z', 'pinky_end_l_QX',
#        'pinky_end_l_QY', 'pinky_end_l_QZ', 'pinky_end_l_QW',
#        'pinky_end_l_roll', 'pinky_end_l_pitch', 'pinky_end_l_yaw'],
#       dtype='object', length=210)

# %% [markdown]
# Regroups all the coordinates of X

# %%
df['new_col'] = range(1, len(df) + 1)

# %%
# df["X"]=df["Hand_L_x"]+df["thumb_01_l_x"]+df["thumb_02_l_x"]+df["thumb_03_l_x"]+df["thumb_end_l_x"]+df["index_01_l_x"]+df["index_02_l_x"]+df["index_03_l_x"]+df["index_end_l_x"]
colx=['thumb_01_l_x','thumb_02_l_x','thumb_03_l_x','thumb_end_l_x','index_01_l_x','index_02_l_x','index_03_l_x','index_end_l_x','middle_01_l_x','middle_02_l_x','middle_03_l_x','middle_end_l_x','ring_01_l_x','ring_02_l_x','ring_03_l_x','ring_end_l_x','pinky_01_l_x','pinky_02_l_x','pinky_03_l_x','pinky_end_l_x']
df['Hand_L_x'] = df['Hand_L_x'].str.cat(df[colx], sep=',')
df['Hand_L_x']=df['Hand_L_x'].apply(literal_eval) #convert to list type
# df2=df.explode('Hand_L_x').drop_duplicates()
# df2=df['Hand_L_x'].explode()
# df2.drop(['thumb_01_l_x','thumb_02_l_x','thumb_03_l_x','thumb_end_l_x','index_01_l_x','index_02_l_x','index_03_l_x','index_end_l_x','middle_01_l_x','middle_02_l_x','middle_03_l_x','middle_end_l_x','ring_01_l_x','ring_02_l_x','ring_03_l_x','ring_end_l_x','pinky_01_l_x','pinky_02_l_x','pinky_03_l_x','pinky_end_l_x'],1,inplace=True)

# %%
# df2

# %% [markdown]
# Regroups all the coordinates of y

# %%
coly=['thumb_01_l_y','thumb_02_l_y','thumb_03_l_y','thumb_end_l_y','index_01_l_y','index_02_l_y','index_03_l_y','index_end_l_y','middle_01_l_y','middle_02_l_y','middle_03_l_y','middle_end_l_y','ring_01_l_y','ring_02_l_y','ring_03_l_y','ring_end_l_y','pinky_01_l_y','pinky_02_l_y','pinky_03_l_y','pinky_end_l_y']
df['Hand_L_y'] = df['Hand_L_y'].str.cat(df[coly], sep=',')
df['Hand_L_y']=df['Hand_L_y'].apply(literal_eval) #convert to list type
# df=df.explode('Hand_L_y').drop_duplicates()
# df2=df.set_index(['Hand_L_z']).apply(pd.Series.explode).reset_index()
# df.drop(['thumb_01_l_y','thumb_02_l_y','thumb_03_l_y','thumb_end_l_y','index_01_l_y','index_02_l_y','index_03_l_y','index_end_l_y','middle_01_l_y','middle_02_l_y','middle_03_l_y','middle_end_l_y','ring_01_l_y','ring_02_l_y','ring_03_l_y','ring_end_l_y','pinky_01_l_y','pinky_02_l_y','pinky_03_l_y','pinky_end_l_y'],1,inplace=True)

# %%
# df2

# %% [markdown]
# Regroups all the coordinates of z

# %%
colz=['thumb_01_l_z','thumb_02_l_z','thumb_03_l_z','thumb_end_l_z','index_01_l_z','index_02_l_z','index_03_l_z','index_end_l_z','middle_01_l_z','middle_02_l_z','middle_03_l_z','middle_end_l_z','ring_01_l_z','ring_02_l_z','ring_03_l_z','ring_end_l_z','pinky_01_l_z','pinky_02_l_z','pinky_03_l_z','pinky_end_l_z']
df['Hand_L_z'] = df['Hand_L_z'].str.cat(df[colz], sep=',')
df['Hand_L_z']=df['Hand_L_z'].apply(literal_eval) #convert to list type
# df.explode('Hand_L_z')
# df.drop(['thumb_01_l_z','thumb_02_l_z','thumb_03_l_z','thumb_end_l_z','index_01_l_z','index_02_l_z','index_03_l_z','index_end_l_z','middle_01_l_z','middle_02_l_z','middle_03_l_z','middle_end_l_z','ring_01_l_z','ring_02_l_z','ring_03_l_z','ring_end_l_z','pinky_01_l_z','pinky_02_l_z','pinky_03_l_z','pinky_end_l_z'],1,inplace=True)

# %% [markdown]
# Regroups all the coordinates of QX

# %%
colqx=['thumb_01_l_QX','thumb_02_l_QX','thumb_03_l_QX','thumb_end_l_QX','index_01_l_QX','index_02_l_QX','index_03_l_QX','index_end_l_QX','middle_01_l_QX','middle_02_l_QX','middle_03_l_QX','middle_end_l_QX','ring_01_l_QX','ring_02_l_QX','ring_03_l_QX','ring_end_l_QX','pinky_01_l_QX','pinky_02_l_QX','pinky_03_l_QX','pinky_end_l_QX']
df['Hand_L_QX'] = df['Hand_L_QX'].str.cat(df[colqx], sep=',')
df['Hand_L_QX']=df['Hand_L_QX'].apply(literal_eval) #convert to list type
# df.explode('Hand_L_QX')
# df.drop(['thumb_01_l_QX','thumb_02_l_QX','thumb_03_l_QX','thumb_end_l_QX','index_01_l_QX','index_02_l_QX','index_03_l_QX','index_end_l_QX','middle_01_l_QX','middle_02_l_QX','middle_03_l_QX','middle_end_l_QX','ring_01_l_QX','ring_02_l_QX','ring_03_l_QX','ring_end_l_QX','pinky_01_l_QX','pinky_02_l_QX','pinky_03_l_QX','pinky_end_l_QX'],1,inplace=True)

# %% [markdown]
# Regroups all the coordinates of QY

# %%
colqy=['thumb_01_l_QY','thumb_02_l_QY','thumb_03_l_QY','thumb_end_l_QY','index_01_l_QY','index_02_l_QY','index_03_l_QY','index_end_l_QY','middle_01_l_QY','middle_02_l_QY','middle_03_l_QY','middle_end_l_QY','ring_01_l_QY','ring_02_l_QY','ring_03_l_QY','ring_end_l_QY','pinky_01_l_QY','pinky_02_l_QY','pinky_03_l_QY','pinky_end_l_QY']
df['Hand_L_QY'] = df['Hand_L_QY'].str.cat(df[colqy], sep=',')
df['Hand_L_QY']=df['Hand_L_QY'].apply(literal_eval) #convert to list type
# df.explode('Hand_L_QY')
# df.drop(['thumb_01_l_QY','thumb_02_l_QY','thumb_03_l_QY','thumb_end_l_QY','index_01_l_QY','index_02_l_QY','index_03_l_QY','index_end_l_QY','middle_01_l_QY','middle_02_l_QY','middle_03_l_QY','middle_end_l_QY','ring_01_l_QY','ring_02_l_QY','ring_03_l_QY','ring_end_l_QY','pinky_01_l_QY','pinky_02_l_QY','pinky_03_l_QY','pinky_end_l_QY'],1,inplace=True)

# %% [markdown]
# Regroups all the coordinates of QZ

# %%
colqz=['thumb_01_l_QZ','thumb_02_l_QZ','thumb_03_l_QZ','thumb_end_l_QZ','index_01_l_QZ','index_02_l_QZ','index_03_l_QZ','index_end_l_QZ','middle_01_l_QZ','middle_02_l_QZ','middle_03_l_QZ','middle_end_l_QZ','ring_01_l_QZ','ring_02_l_QZ','ring_03_l_QZ','ring_end_l_QZ','pinky_01_l_QZ','pinky_02_l_QZ','pinky_03_l_QZ','pinky_end_l_QZ']
df['Hand_L_QZ'] = df['Hand_L_QZ'].str.cat(df[colqz], sep=',')
df['Hand_L_QZ']=df['Hand_L_QZ'].apply(literal_eval) #convert to list type
# df.explode('Hand_L_QZ')
# df.drop(['thumb_01_l_QZ','thumb_02_l_QZ','thumb_03_l_QZ','thumb_end_l_QZ','index_01_l_QZ','index_02_l_QZ','index_03_l_QZ','index_end_l_QZ','middle_01_l_QZ','middle_02_l_QZ','middle_03_l_QZ','middle_end_l_QZ','ring_01_l_QZ','ring_02_l_QZ','ring_03_l_QZ','ring_end_l_QZ','pinky_01_l_QZ','pinky_02_l_QZ','pinky_03_l_QZ','pinky_end_l_QZ'],1,inplace=True)

# %% [markdown]
# Regroups all the coordinates of QW

# %%
colqw=['thumb_01_l_QW','thumb_02_l_QW','thumb_03_l_QW','thumb_end_l_QW','index_01_l_QW','index_02_l_QW','index_03_l_QW','index_end_l_QW','middle_01_l_QW','middle_02_l_QW','middle_03_l_QW','middle_end_l_QW','ring_01_l_QW','ring_02_l_QW','ring_03_l_QW','ring_end_l_QW','pinky_01_l_QW','pinky_02_l_QW','pinky_03_l_QW','pinky_end_l_QW']
df['Hand_L_QW'] = df['Hand_L_QW'].str.cat(df[colqw], sep=',')
df['Hand_L_QW']=df['Hand_L_QW'].apply(literal_eval) #convert to list type
# df.explode('Hand_L_QW')
# df.drop(['thumb_01_l_QW','thumb_02_l_QW','thumb_03_l_QW','thumb_end_l_QW','index_01_l_QW','index_02_l_QW','index_03_l_QW','index_end_l_QW','middle_01_l_QW','middle_02_l_QW','middle_03_l_QW','middle_end_l_QW','ring_01_l_QW','ring_02_l_QW','ring_03_l_QW','ring_end_l_QW','pinky_01_l_QW','pinky_02_l_QW','pinky_03_l_QW','pinky_end_l_QW'],1,inplace=True)

# %% [markdown]
# Regroups all the coordinates of roll

# %%
colroll=['thumb_01_l_roll','thumb_02_l_roll','thumb_03_l_roll','thumb_end_l_roll','index_01_l_roll','index_02_l_roll','index_03_l_roll','index_end_l_roll','middle_01_l_roll','middle_02_l_roll','middle_03_l_roll','middle_end_l_roll','ring_01_l_roll','ring_02_l_roll','ring_03_l_roll','ring_end_l_roll','pinky_01_l_roll','pinky_02_l_roll','pinky_03_l_roll','pinky_end_l_roll']
df['Hand_L_roll'] = df['Hand_L_roll'].str.cat(df[colroll], sep=',')
df['Hand_L_roll']=df['Hand_L_roll'].apply(literal_eval) #convert to list type
# df.explode('Hand_L_roll')
# df.drop(['thumb_01_l_roll','thumb_02_l_roll','thumb_03_l_roll','thumb_end_l_roll','index_01_l_roll','index_02_l_roll','index_03_l_roll','index_end_l_roll','middle_01_l_roll','middle_02_l_roll','middle_03_l_roll','middle_end_l_roll','ring_01_l_roll','ring_02_l_roll','ring_03_l_roll','ring_end_l_roll','pinky_01_l_roll','pinky_02_l_roll','pinky_03_l_roll','pinky_end_l_roll'],1,inplace=True)

# %% [markdown]
# Regroups all the coordinates of pitch

# %%
colpitch=['thumb_01_l_pitch','thumb_02_l_pitch','thumb_03_l_pitch','thumb_end_l_pitch','index_01_l_pitch','index_02_l_pitch','index_03_l_pitch','index_end_l_pitch','middle_01_l_pitch','middle_02_l_pitch','middle_03_l_pitch','middle_end_l_pitch','ring_01_l_pitch','ring_02_l_pitch','ring_03_l_pitch','ring_end_l_pitch','pinky_01_l_pitch','pinky_02_l_pitch','pinky_03_l_pitch','pinky_end_l_pitch']
df['Hand_L_pitch'] = df['Hand_L_pitch'].str.cat(df[colpitch], sep=',')
df['Hand_L_pitch']=df['Hand_L_pitch'].apply(literal_eval) #convert to list type
# df.explode('Hand_L_pitch')
# df.drop(['thumb_01_l_pitch','thumb_02_l_pitch','thumb_03_l_pitch','thumb_end_l_pitch','index_01_l_pitch','index_02_l_pitch','index_03_l_pitch','index_end_l_pitch','middle_01_l_pitch','middle_02_l_pitch','middle_03_l_pitch','middle_end_l_pitch','ring_01_l_pitch','ring_02_l_pitch','ring_03_l_pitch','ring_end_l_pitch','pinky_01_l_pitch','pinky_02_l_pitch','pinky_03_l_pitch','pinky_end_l_pitch'],1,inplace=True)

# %% [markdown]
# Regroups all the coordinates of yaw

# %%
colyaw=['thumb_01_l_yaw','thumb_02_l_yaw','thumb_03_l_yaw','thumb_end_l_yaw','index_01_l_yaw','index_02_l_yaw','index_03_l_yaw','index_end_l_yaw','middle_01_l_yaw','middle_02_l_yaw','middle_03_l_yaw','middle_end_l_yaw','ring_01_l_yaw','ring_02_l_yaw','ring_03_l_yaw','ring_end_l_yaw','pinky_01_l_yaw','pinky_02_l_yaw','pinky_03_l_yaw','pinky_end_l_yaw']
df['Hand_L_yaw'] = df['Hand_L_yaw'].str.cat(df[colyaw], sep=',')
df['Hand_L_yaw']=df['Hand_L_yaw'].apply(literal_eval) #convert to list type
# df.explode('Hand_L_yaw')
# df.drop(['thumb_01_l_yaw','thumb_02_l_yaw','thumb_03_l_yaw','thumb_end_l_yaw','index_01_l_yaw','index_02_l_yaw','index_03_l_yaw','index_end_l_yaw','middle_01_l_yaw','middle_02_l_yaw','middle_03_l_yaw','middle_end_l_yaw','ring_01_l_yaw','ring_02_l_yaw','ring_03_l_yaw','ring_end_l_yaw','pinky_01_l_yaw','pinky_02_l_yaw','pinky_03_l_yaw','pinky_end_l_yaw'],1,inplace=True)

# %%
df2=df.set_index(['new_col']).apply(pd.Series.explode).reset_index()

# %% [markdown]
# DROP

# %%
df2.drop(['thumb_01_l_x','thumb_02_l_x','thumb_03_l_x','thumb_end_l_x','index_01_l_x','index_02_l_x','index_03_l_x','index_end_l_x','middle_01_l_x','middle_02_l_x','middle_03_l_x','middle_end_l_x','ring_01_l_x','ring_02_l_x','ring_03_l_x','ring_end_l_x','pinky_01_l_x','pinky_02_l_x','pinky_03_l_x','pinky_end_l_x',
'thumb_01_l_y','thumb_02_l_y','thumb_03_l_y','thumb_end_l_y','index_01_l_y','index_02_l_y','index_03_l_y','index_end_l_y','middle_01_l_y','middle_02_l_y','middle_03_l_y','middle_end_l_y','ring_01_l_y','ring_02_l_y','ring_03_l_y','ring_end_l_y','pinky_01_l_y','pinky_02_l_y','pinky_03_l_y','pinky_end_l_y',
'thumb_01_l_z','thumb_02_l_z','thumb_03_l_z','thumb_end_l_z','index_01_l_z','index_02_l_z','index_03_l_z','index_end_l_z','middle_01_l_z','middle_02_l_z','middle_03_l_z','middle_end_l_z','ring_01_l_z','ring_02_l_z','ring_03_l_z','ring_end_l_z','pinky_01_l_z','pinky_02_l_z','pinky_03_l_z','pinky_end_l_z',
'thumb_01_l_QX','thumb_02_l_QX','thumb_03_l_QX','thumb_end_l_QX','index_01_l_QX','index_02_l_QX','index_03_l_QX','index_end_l_QX','middle_01_l_QX','middle_02_l_QX','middle_03_l_QX','middle_end_l_QX','ring_01_l_QX','ring_02_l_QX','ring_03_l_QX','ring_end_l_QX','pinky_01_l_QX','pinky_02_l_QX','pinky_03_l_QX','pinky_end_l_QX',
'thumb_01_l_QY','thumb_02_l_QY','thumb_03_l_QY','thumb_end_l_QY','index_01_l_QY','index_02_l_QY','index_03_l_QY','index_end_l_QY','middle_01_l_QY','middle_02_l_QY','middle_03_l_QY','middle_end_l_QY','ring_01_l_QY','ring_02_l_QY','ring_03_l_QY','ring_end_l_QY','pinky_01_l_QY','pinky_02_l_QY','pinky_03_l_QY','pinky_end_l_QY',
'thumb_01_l_QW','thumb_02_l_QW','thumb_03_l_QW','thumb_end_l_QW','index_01_l_QW','index_02_l_QW','index_03_l_QW','index_end_l_QW','middle_01_l_QW','middle_02_l_QW','middle_03_l_QW','middle_end_l_QW','ring_01_l_QW','ring_02_l_QW','ring_03_l_QW','ring_end_l_QW','pinky_01_l_QW','pinky_02_l_QW','pinky_03_l_QW','pinky_end_l_QW',
'thumb_01_l_QZ','thumb_02_l_QZ','thumb_03_l_QZ','thumb_end_l_QZ','index_01_l_QZ','index_02_l_QZ','index_03_l_QZ','index_end_l_QZ','middle_01_l_QZ','middle_02_l_QZ','middle_03_l_QZ','middle_end_l_QZ','ring_01_l_QZ','ring_02_l_QZ','ring_03_l_QZ','ring_end_l_QZ','pinky_01_l_QZ','pinky_02_l_QZ','pinky_03_l_QZ','pinky_end_l_QZ',
'thumb_01_l_roll','thumb_02_l_roll','thumb_03_l_roll','thumb_end_l_roll','index_01_l_roll','index_02_l_roll','index_03_l_roll','index_end_l_roll','middle_01_l_roll','middle_02_l_roll','middle_03_l_roll','middle_end_l_roll','ring_01_l_roll','ring_02_l_roll','ring_03_l_roll','ring_end_l_roll','pinky_01_l_roll','pinky_02_l_roll','pinky_03_l_roll','pinky_end_l_roll',
'thumb_01_l_pitch','thumb_02_l_pitch','thumb_03_l_pitch','thumb_end_l_pitch','index_01_l_pitch','index_02_l_pitch','index_03_l_pitch','index_end_l_pitch','middle_01_l_pitch','middle_02_l_pitch','middle_03_l_pitch','middle_end_l_pitch','ring_01_l_pitch','ring_02_l_pitch','ring_03_l_pitch','ring_end_l_pitch','pinky_01_l_pitch','pinky_02_l_pitch','pinky_03_l_pitch','pinky_end_l_pitch',
'thumb_01_l_yaw','thumb_02_l_yaw','thumb_03_l_yaw','thumb_end_l_yaw','index_01_l_yaw','index_02_l_yaw','index_03_l_yaw','index_end_l_yaw','middle_01_l_yaw','middle_02_l_yaw','middle_03_l_yaw','middle_end_l_yaw','ring_01_l_yaw','ring_02_l_yaw','ring_03_l_yaw','ring_end_l_yaw','pinky_01_l_yaw','pinky_02_l_yaw','pinky_03_l_yaw','pinky_end_l_yaw',
'new_col'],1,inplace=True)
# Out:
# /tmp/ipykernel_14313/4117096739.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df2.drop(['thumb_01_l_x','thumb_02_l_x','thumb_03_l_x','thumb_end_l_x','index_01_l_x','index_02_l_x','index_03_l_x','index_end_l_x','middle_01_l_x','middle_02_l_x','middle_03_l_x','middle_end_l_x','ring_01_l_x','ring_02_l_x','ring_03_l_x','ring_end_l_x','pinky_01_l_x','pinky_02_l_x','pinky_03_l_x','pinky_end_l_x',

# %% [markdown]
# RENAME

# %%
df2.rename(columns = {'Hand_L_x':'x', 
  'Hand_L_y':'y', 
  'Hand_L_z':'z', 
  'Hand_L_QX':'QX', 
  'Hand_L_QY':'QY', 
  'Hand_L_QZ':'QZ', 
  'Hand_L_QW':'QW', 
  'Hand_L_roll':'roll', 
  'Hand_L_pitch':'pitch', 
  'Hand_L_yaw':'yaw'},inplace=True)

# %%
df2
# Out:
#                x          y           z        QX        QY        QZ  \
# 0      50.017609  88.463943  153.403961  0.674645  0.330493  0.636429
# 1      46.725128  90.036003  153.622543   0.18054 -0.124758  0.818622
# 2      45.441483  92.883545  155.101807  0.200739 -0.073666  0.734346
# 3      45.231827  95.033531  156.016006  0.203154 -0.099407   0.71751
# 4      45.142918   96.66227  156.776413  0.203154 -0.099407   0.71751
# ...          ...        ...         ...       ...       ...       ...
# 41575  17.308819  47.641865  100.904488  0.330318  0.686394  0.214694
# 41576   18.72044  41.764729  103.899277   0.33972  0.640739  0.408623
# 41577  18.378511  43.723621  102.945473  0.225031  0.689426   0.30773
# 41578  18.142448   44.88586  101.747147  0.082229  0.720557   0.17799
# 41579  18.016815  45.324467  100.599953  0.082229  0.720557   0.17799
#
#              QW        roll      pitch         yaw
# 0       0.17489  -101.09272  47.998539   92.444099
# ...

# %%
print(df2.x.head(50))
# Out:
# 0     50.017609
# 1     46.725128
# 2     45.441483
# 3     45.231827
# 4     45.142918
# 5      47.69574
# 6     47.658314
# 7     47.599083
# 8     47.484665
# 9     49.413441
# 10    49.314125
# 11     49.18663
# 12    48.983841
# 13    50.977348
# 14    50.814442
# 15    50.627983
# 16    50.318398
# 17    52.478489
# 18    51.866936
# 19    51.607529
# 20    51.824371
# 21    -2.965618
# 22    -3.322281
# 23    -5.796345
# 24    -7.974213
# 25    -9.473385
# 26    -8.221294
# 27    -9.769444
# 28    -7.970169
# 29    -7.110062
# 30    -8.968307
# 31   -10.697166
# 32    -8.679279
# 33    -7.783894
# 34     -9.70763
# 35   -11.349407
# 36    -9.490826
# 37    -8.561695
# 38   -10.390236
# 39   -12.725182
# 40   -12.304241
# 41   -11.129612
# 42    27.818623
# 43    29.414574
# 44    29.452217
# 45    29.094116
# 46    29.485901
# 47    24.361933
# 48    23.433691
# 49    24.817226
# Name: x, dtype: object

# %% [markdown]
# 0 to 20

# %%
import open3d as o3d
from pyntcloud import PyntCloud
# def main(data):
#     pts = np.random.randint(0, 100, (100, 3))

#     # whether to write in binary or text format
#     write_text = True

#     # use open3d
#     use_o3d(pts, write_text)


def use_o3d(pts, write_text):
    # pcd = o3d.geometry.PointCloud()
    pcd=PyntCloud(pd.DataFrame(pts))

    # the method Vector3dVector() will convert numpy array of shape (n, 3) to Open3D format.
    # see http://www.open3d.org/docs/release/python_api/open3d.utility.Vector3dVector.html#open3d.utility.Vector3dVector
    # pcd.points = o3d.utility.Vector3dVector(pts)

    # http://www.open3d.org/docs/release/python_api/open3d.io.write_point_cloud.html#open3d.io.write_point_cloud
    o3d.io.write_point_cloud("my_pts.ply", pcd, write_ascii=write_text)

    # read ply file
    pcd = o3d.io.read_point_cloud('my_pts.ply')

    # visualize
    # o3d.visualization.draw_geometries([pcd])
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# df2=df2.astype(float)

# %%
import open3d as o3d
from pyntcloud import PyntCloud
import copy
from scipy.spatial.transform import Rotation as R

df2=df2.astype(str)
def visualisation(data):

    #going through attributeNames one by one and extracting x y z qx qy qz qw roll pitch yaw for each name 
    # + creating a new line in the data frame containing all the values
    # for i in range(len(data)):
        # for j in range(11):
            selectdata=data.loc[0:20]
            # print(selectdata)
            xyz=selectdata.filter(regex='x$|y$|z$')
            # qxqyqzqw=selectdata.filter(regex='QX$|QY$|QZ$|QW$')
            # write_text=True
            # use_o3d(news,write_text)
            # print(news)
            # cloud = PyntCloud(pd.DataFrame(news))
            # print(cloud)
            # print(cloud.points.describe())
            # cloud.to_file("output.ply",points)
            with open('points.txt', 'w') as f:
                f.write(str(xyz))
            # pymesh.save_mesh("tmp.stl", qxqyqz, ascii=True)
            pcd=o3d.io.read_point_cloud('points.txt', format='xyz')
            # quat_w = df2[["QW"]].loc[0:19].apply(literal_eval)
            # quat_i = df2[["QX"]].loc[0:19].apply(literal_eval)
            # quat_j = df2[["QY"]].loc[0:19].apply(literal_eval)
            # quat_k = df2[["QZ"]].loc[0:19].apply(literal_eval)
            qyqzqw=['QY','QZ','QW']
            df2['QX']= df2['QX'].str.cat(df2[qyqzqw], sep=',')
            df2['QX']=df2['QX'].apply(literal_eval) 
            quat = df2['QX'][21]
            # quat = np.array([quat_i, quat_j, quat_k, quat_w]).T
            # quatx = np.resize(quat_i, (4,))
            # quaty = np.resize(quat_j, (4,))
            # quatz = np.resize(quat_k, (4,))
            # quatw = np.resize(quat_w, (4,))
            # quat = np.array([quatx, quaty, quatz, quatw]).T
            # rot=o3d.geometry.get_rotation_matrix_from_quaternion(np.array(quat))
            mat = o3d.geometry.get_rotation_matrix_from_quaternion(np.array(quat))
      

            # T = np.eye(4)
            # T[0:3, 3] = np.array(xyz)
            # T[0:3, 0:3] = np.array(mat)
            # coordinate_frame = o3d.geometry.TriangleMesh.create_coordinate_frame(size=1.0)
            # coordinate_frame.transform(T)
            # print(T)
            # mesh = o3d.geometry.TriangleMesh.create_coordinate_frame()
            # mesh_t = copy.deepcopy(mesh).transform(T)
            # o3d.visualization.draw_geometries([pcd,mesh_t])
            # vis.add_geometry(coordinate_frame)
            # print(quat)
            # rot = R.from_quat(quat)
            o3d.visualization.draw_geometries([pcd, mat],
                                  )
            # mesh = o3d.geometry.TriangleMesh.create_coordinate_frame()
            # mesh_tx = copy.deepcopy(mesh).translate((1.3, 0, 0))
            # mesh_ty = copy.deepcopy(mesh).translate((0, 1.3, 0))
            # o3d.visualization.draw_geometries([pcd,df2.QX.loc[0:20],df2.QY.loc[0:20],df2.QZ.loc[0:20],df2.QW.loc[0:20]])

                     
# visualisation(df2)

# %%
# import open3d as o3d
# from pyntcloud import PyntCloud
# print("Load a ply point cloud, print it, and render it")
# pcd = o3d.io.read_point_cloud(position_ws, format='xyz')
# # print(pcd)
# # print(np.asarray(pcd.points))
# # origin = o3d.geometry.TriangleMesh.create_coordinate_frame(size=0.5, origin=[-2,-2,-2])
# # geometries = [pcd, origin]
# o3d.visualization.draw_geometries([pcd],
#                                   )

# %%
df2=df2.astype(str)
# yz=['y','z']
# position_ws=df2['x'].str.cat(df2[yz], sep=',')

# rotation_ws=df2.groupby(['QX','QY','QZ','QW'])

# euler=df.groupby([)

# %%
for i in range(len(df2)):
    a=i

print(a)
# Out:
# 41579

# %%
import open3d as o3d
from pyntcloud import PyntCloud
import json

# print("Load a ply point cloud, print it, and render it")
# dataxyz=
# pcd = o3d.io.read_point_cloud("ODS_bunny_a.ply")
# print(pcd)
# print(np.asarray(pcd.points))
# origin = o3d.geometry.TriangleMesh.create_coordinate_frame(size=0.5,origin=[-2, -2, -2])
# geometries = [pcd, origin]

# points = pd.DataFrame(np.random.rand(1000, 3))

# cloud = PyntCloud(convertcmtom(df))

# o3d.visualization.draw_geometries([cloud],
#                                   )
# df2['lb'] = range(1, len(df2) + 1)

yz=['y','z']
df2['x']= df2['x'].str.cat(df2[yz], sep=', ')
df2['x']=df2['x'].apply(literal_eval) 

qyqzqw=['QY','QZ','QW']
df2['QX']= df2['QX'].str.cat(df2[qyqzqw], sep=',')
# print(df2["x"][3])
# df2.astype(float)
df2['QX']=df2['QX'].apply(literal_eval) 
# rotation_ws=[0.674645,0.330493,0.636429,0.17489]
# print(df2['x'])

def vis_hand_plot_o3d(hand_data):
    vis = o3d.visualization.Visualizer()
    vis.create_window()

    # for lb in range(len(hand_data)):
    for lb in range(21):
        # pos = hand_data[lb]['position_ws']
        pos = hand_data['x'][lb]
        # pos= position_ws
        quat = hand_data['QX'][lb]
        # quat=rotation_ws
        mat = o3d.geometry.get_rotation_matrix_from_quaternion(np.array(quat))
        # mat = euler
        # hand_data=hand_data.astype(float)
        T = np.eye(4)
        T[0:3, 3] = np.array(pos)
        T[0:3, 0:3] = np.array(mat)
        coordinate_frame = o3d.geometry.TriangleMesh.create_coordinate_frame(size=1.0)
        coordinate_frame.transform(T)
        vis.add_geometry(coordinate_frame)

    vis.poll_events()
    vis.update_renderer()
    vis.run()


vis_hand_plot_o3d(df2)
